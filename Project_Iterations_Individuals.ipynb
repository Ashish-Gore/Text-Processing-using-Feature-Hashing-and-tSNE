# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # Android Project

# %%
import pandas as pd
Android_10 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Android/Ex2_RQ3_Android_10.csv.xlsx')
Android_20 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Android/Ex2_RQ3_Android_20.csv.xlsx')
Android_30 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Android/Ex2_RQ3_Android_30.csv.xlsx')
Android_40 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Android/Ex2_RQ3_Android_40.csv.xlsx')
Android_50 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Android/Ex2_RQ3_Android_50.csv.xlsx')
Android_60 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Android/Ex2_RQ3_Android_60.csv.xlsx')
Android_70 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Android/Ex2_RQ3_Android_70.csv.xlsx')
Android_80 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Android/Ex2_RQ3_Android_80.csv.xlsx')
Android_90 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Android/Ex2_RQ3_Android_90.csv.xlsx')
Android_100 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Android/Ex2_RQ3_Android_100.csv.xlsx')

#Data cleaning and preprocessing
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
Android_10_corpus = []
for i in range(0, len(Android_10)):
    review = re.sub('[^a-zA-Z]', ' ', Android_10['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Android_10_corpus.append(review)

Android_20_corpus = []
for i in range(0, len(Android_20)):
    review = re.sub('[^a-zA-Z]', ' ', Android_20['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Android_20_corpus.append(review)

Android_30_corpus = []
for i in range(0, len(Android_30)):
    review = re.sub('[^a-zA-Z]', ' ', Android_30['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Android_30_corpus.append(review)

Android_40_corpus = []
for i in range(0, len(Android_40)):
    review = re.sub('[^a-zA-Z]', ' ', Android_40['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Android_40_corpus.append(review)

Android_50_corpus = []
for i in range(0, len(Android_50)):
    review = re.sub('[^a-zA-Z]', ' ', Android_50['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Android_50_corpus.append(review)

Android_60_corpus = []
for i in range(0, len(Android_60)):
    review = re.sub('[^a-zA-Z]', ' ', Android_60['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Android_60_corpus.append(review)

Android_70_corpus = []
for i in range(0, len(Android_70)):
    review = re.sub('[^a-zA-Z]', ' ', Android_70['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Android_70_corpus.append(review)

Android_80_corpus = []
for i in range(0, len(Android_80)):
    review = re.sub('[^a-zA-Z]', ' ', Android_80['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Android_80_corpus.append(review)

Android_90_corpus = []
for i in range(0, len(Android_90)):
    review = re.sub('[^a-zA-Z]', ' ', Android_90['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Android_90_corpus.append(review)

Android_100_corpus = []
for i in range(0, len(Android_100)):
    review = re.sub('[^a-zA-Z]', ' ', Android_100['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Android_100_corpus.append(review)

def token_features(token, part_of_speech):
    if token.isdigit():
        yield "numeric"
    else:
        yield "token={}".format(token.lower())
        yield "token,pos={},{}".format(token, part_of_speech)
    if token[0].isupper():
        yield "uppercase_initial"
    if token.isupper():
        yield "all_uppercase"
    yield "pos={}".format(part_of_speech)

import nltk
nltk.download('averaged_perceptron_tagger')
from sklearn.feature_extraction import FeatureHasher
from nltk import pos_tag, word_tokenize

raw_X = (token_features(tok, pos_tag(tok)) for tok in Android_10_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Android_10_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Android_20_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Android_20_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Android_30_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Android_30_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Android_40_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Android_40_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Android_50_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Android_50_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Android_60_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Android_60_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Android_70_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Android_70_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Android_80_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Android_80_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Android_90_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Android_90_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Android_100_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Android_100_Hasher = hasher.transform(raw_X)


from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
m = TSNE(learning_rate=200)

tsne_features = m.fit_transform(Android_10_Hasher.toarray())
Android_10['x'] = tsne_features[:,0]
Android_10['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Android_20_Hasher.toarray())
Android_20['x'] = tsne_features[:,0]
Android_20['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Android_30_Hasher.toarray())
Android_30['x'] = tsne_features[:,0]
Android_30['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Android_40_Hasher.toarray())
Android_40['x'] = tsne_features[:,0]
Android_40['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Android_50_Hasher.toarray())
Android_50['x'] = tsne_features[:,0]
Android_50['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Android_60_Hasher.toarray())
Android_60['x'] = tsne_features[:,0]
Android_60['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Android_70_Hasher.toarray())
Android_70['x'] = tsne_features[:,0]
Android_70['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Android_80_Hasher.toarray())
Android_80['x'] = tsne_features[:,0]
Android_80['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Android_90_Hasher.toarray())
Android_90['x'] = tsne_features[:,0]
Android_90['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Android_100_Hasher.toarray())
Android_100['x'] = tsne_features[:,0]
Android_100['y'] = tsne_features[:,1]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
# Plotting Final Figures
sns.set_style("whitegrid")
f, axes = plt.subplots(2, 5,figsize=(20, 8))

axes[1][0].set_ylabel(r"Android", fontsize=18,)
sns.scatterplot(x="x", y="y", hue='BRA', data= Android_10, ax= axes[0][0], legend= False)
axes[0][0].set_title("Iteration 1")
sns.scatterplot(x="x", y="y", hue='BRA', data= Android_20, ax= axes[0][1], legend= False)
axes[0][1].set_title("Iteration 2")
sns.scatterplot(x="x", y="y", hue='BRA', data= Android_30, ax= axes[0][2], legend= False)
axes[0][2].set_title("Iteration 3")
sns.scatterplot(x="x", y="y", hue='BRA', data= Android_40, ax= axes[0][3], legend= False)
axes[0][3].set_title("Iteration 4")
sns.scatterplot(x="x", y="y", hue='BRA', data= Android_50, ax= axes[0][4], )
axes[0][4].set_title("Iteration 5")
sns.scatterplot(x="x", y="y", hue='BRA', data= Android_60, ax= axes[1][0], legend= False)
axes[1][0].set_title("Iteration 6")
sns.scatterplot(x="x", y="y", hue='BRA', data= Android_70, ax= axes[1][1], legend= False)
axes[1][1].set_title("Iteration 7")
sns.scatterplot(x="x", y="y", hue='BRA', data= Android_80, ax= axes[1][2], legend= False)
axes[1][2].set_title("Iteration 8")
sns.scatterplot(x="x", y="y", hue='BRA', data= Android_90, ax= axes[1][3], legend= False)
axes[1][3].set_title("Iteration 9")
sns.scatterplot(x="x", y="y", hue='BRA', data= Android_100, ax= axes[1][4], legend= False)
axes[1][4].set_title("Iteration 10",)

for ax in axes:
  for axe in ax:
    axe.set_xlabel('')
    axe.set_ylabel('')
axes[1][0].set_ylabel(r"Android", fontsize=18, color="blue")
# Out:
# Text(0, 0.5, 'Android')

# %% [markdown]
# # Chrome Project

# %%
import pandas as pd
Chrome_10 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Chrome/Ex2_RQ3_Chrome_10.csv.xlsx')
Chrome_20 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Chrome/Ex2_RQ3_Chrome_20.csv.xlsx')
Chrome_30 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Chrome/Ex2_RQ3_Chrome_30.csv.xlsx')
Chrome_40 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Chrome/Ex2_RQ3_Chrome_40.csv.xlsx')
Chrome_50 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Chrome/Ex2_RQ3_Chrome_50.csv.xlsx')
Chrome_60 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Chrome/Ex2_RQ3_Chrome_60.csv.xlsx')
Chrome_70 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Chrome/Ex2_RQ3_Chrome_70.csv.xlsx')
Chrome_80 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Chrome/Ex2_RQ3_Chrome_80.csv.xlsx')
Chrome_90 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Chrome/Ex2_RQ3_Chrome_90.csv.xlsx')
Chrome_100 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Chrome/Ex2_RQ3_Chrome_100.csv.xlsx')

#Data cleaning and preprocessing
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
Chrome_10_corpus = []
for i in range(0, len(Chrome_10)):
    review = re.sub('[^a-zA-Z]', ' ', Chrome_10['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Chrome_10_corpus.append(review)

Chrome_20_corpus = []
for i in range(0, len(Chrome_20)):
    review = re.sub('[^a-zA-Z]', ' ', Chrome_20['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Chrome_20_corpus.append(review)

Chrome_30_corpus = []
for i in range(0, len(Chrome_30)):
    review = re.sub('[^a-zA-Z]', ' ', Chrome_30['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Chrome_30_corpus.append(review)

Chrome_40_corpus = []
for i in range(0, len(Chrome_40)):
    review = re.sub('[^a-zA-Z]', ' ', Chrome_40['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Chrome_40_corpus.append(review)

Chrome_50_corpus = []
for i in range(0, len(Chrome_50)):
    review = re.sub('[^a-zA-Z]', ' ', Chrome_50['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Chrome_50_corpus.append(review)

Chrome_60_corpus = []
for i in range(0, len(Chrome_60)):
    review = re.sub('[^a-zA-Z]', ' ', Chrome_60['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Chrome_60_corpus.append(review)

Chrome_70_corpus = []
for i in range(0, len(Chrome_70)):
    review = re.sub('[^a-zA-Z]', ' ', Chrome_70['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Chrome_70_corpus.append(review)

Chrome_80_corpus = []
for i in range(0, len(Chrome_80)):
    review = re.sub('[^a-zA-Z]', ' ', Chrome_80['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Chrome_80_corpus.append(review)

Chrome_90_corpus = []
for i in range(0, len(Chrome_90)):
    review = re.sub('[^a-zA-Z]', ' ', Chrome_90['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Chrome_90_corpus.append(review)

Chrome_100_corpus = []
for i in range(0, len(Chrome_100)):
    review = re.sub('[^a-zA-Z]', ' ', Chrome_100['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Chrome_100_corpus.append(review)

def token_features(token, part_of_speech):
    if token.isdigit():
        yield "numeric"
    else:
        yield "token={}".format(token.lower())
        yield "token,pos={},{}".format(token, part_of_speech)
    if token[0].isupper():
        yield "uppercase_initial"
    if token.isupper():
        yield "all_uppercase"
    yield "pos={}".format(part_of_speech)

import nltk
nltk.download('averaged_perceptron_tagger')
from sklearn.feature_extraction import FeatureHasher
from nltk import pos_tag, word_tokenize

raw_X = (token_features(tok, pos_tag(tok)) for tok in Chrome_10_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Chrome_10_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Chrome_20_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Chrome_20_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Chrome_30_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Chrome_30_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Chrome_40_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Chrome_40_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Chrome_50_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Chrome_50_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Chrome_60_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Chrome_60_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Chrome_70_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Chrome_70_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Chrome_80_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Chrome_80_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Chrome_90_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Chrome_90_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Chrome_100_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Chrome_100_Hasher = hasher.transform(raw_X)


from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
m = TSNE(learning_rate=200)

tsne_features = m.fit_transform(Chrome_10_Hasher.toarray())
Chrome_10['x'] = tsne_features[:,0]
Chrome_10['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Chrome_20_Hasher.toarray())
Chrome_20['x'] = tsne_features[:,0]
Chrome_20['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Chrome_30_Hasher.toarray())
Chrome_30['x'] = tsne_features[:,0]
Chrome_30['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Chrome_40_Hasher.toarray())
Chrome_40['x'] = tsne_features[:,0]
Chrome_40['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Chrome_50_Hasher.toarray())
Chrome_50['x'] = tsne_features[:,0]
Chrome_50['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Chrome_60_Hasher.toarray())
Chrome_60['x'] = tsne_features[:,0]
Chrome_60['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Chrome_70_Hasher.toarray())
Chrome_70['x'] = tsne_features[:,0]
Chrome_70['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Chrome_80_Hasher.toarray())
Chrome_80['x'] = tsne_features[:,0]
Chrome_80['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Chrome_90_Hasher.toarray())
Chrome_90['x'] = tsne_features[:,0]
Chrome_90['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Chrome_100_Hasher.toarray())
Chrome_100['x'] = tsne_features[:,0]
Chrome_100['y'] = tsne_features[:,1]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Plotting Final Figures
sns.set_style("whitegrid")
f, axes = plt.subplots(2, 5,figsize=(20, 8))

axes[1][0].set_ylabel(r"Chrome", fontsize=18,)
sns.scatterplot(x="x", y="y", hue='BRA', data= Chrome_10, ax= axes[0][0], legend= False)
axes[0][0].set_title("Iteration 1")
sns.scatterplot(x="x", y="y", hue='BRA', data= Chrome_20, ax= axes[0][1], legend= False)
axes[0][1].set_title("Iteration 2")
sns.scatterplot(x="x", y="y", hue='BRA', data= Chrome_30, ax= axes[0][2], legend= False)
axes[0][2].set_title("Iteration 3")
sns.scatterplot(x="x", y="y", hue='BRA', data= Chrome_40, ax= axes[0][3], legend= False)
axes[0][3].set_title("Iteration 4")
sns.scatterplot(x="x", y="y", hue='BRA', data= Chrome_50, ax= axes[0][4], )
axes[0][4].set_title("Iteration 5")
sns.scatterplot(x="x", y="y", hue='BRA', data= Chrome_60, ax= axes[1][0], legend= False)
axes[1][0].set_title("Iteration 6")
sns.scatterplot(x="x", y="y", hue='BRA', data= Chrome_70, ax= axes[1][1], legend= False)
axes[1][1].set_title("Iteration 7")
sns.scatterplot(x="x", y="y", hue='BRA', data= Chrome_80, ax= axes[1][2], legend= False)
axes[1][2].set_title("Iteration 8")
sns.scatterplot(x="x", y="y", hue='BRA', data= Chrome_90, ax= axes[1][3], legend= False)
axes[1][3].set_title("Iteration 9")
sns.scatterplot(x="x", y="y", hue='BRA', data= Chrome_100, ax= axes[1][4], legend= False)
axes[1][4].set_title("Iteration 10",)

for ax in axes:
  for axe in ax:
    axe.set_xlabel('')
    axe.set_ylabel('')
axes[1][0].set_ylabel(r"Chrome", fontsize=18, color="blue")
# Out:
# Text(0, 0.5, 'Chrome')

# %% [markdown]
# # Core Project

# %%
import pandas as pd
Core_10 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Core/Ex2_RQ3_Core_10.csv.xlsx')
Core_20 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Core/Ex2_RQ3_Core_20.csv.xlsx')
Core_30 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Core/Ex2_RQ3_Core_30.csv.xlsx')
Core_40 = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Core/Ex2_RQ3_Core_40.csv')
Core_50 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Core/Ex2_RQ3_Core_50.csv.xlsx')
Core_60 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Core/Ex2_RQ3_Core_60.csv.xlsx')
Core_70 = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Core/Ex2_RQ3_Core_70.csv')
Core_80 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Core/Ex2_RQ3_Core_80.csv.xlsx')
Core_90 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Core/Ex2_RQ3_Core_90.csv.xlsx')
Core_100 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Core/Ex2_RQ3_Core_100.csv.xlsx')

#Data cleaning and preprocessing
import re
import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
Core_10_corpus = []
for i in range(0, len(Core_10)):
    review = re.sub('[^a-zA-Z]', ' ', Core_10['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Core_10_corpus.append(review)

Core_20_corpus = []
for i in range(0, len(Core_20)):
    review = re.sub('[^a-zA-Z]', ' ', Core_20['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Core_20_corpus.append(review)

Core_30_corpus = []
for i in range(0, len(Core_30)):
    review = re.sub('[^a-zA-Z]', ' ', Core_30['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Core_30_corpus.append(review)

Core_40_corpus = []
for i in range(0, len(Core_40)):
    review = re.sub('[^a-zA-Z]', ' ', Core_40['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Core_40_corpus.append(review)

Core_50_corpus = []
for i in range(0, len(Core_50)):
    review = re.sub('[^a-zA-Z]', ' ', Core_50['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Core_50_corpus.append(review)

Core_60_corpus = []
for i in range(0, len(Core_60)):
    review = re.sub('[^a-zA-Z]', ' ', Core_60['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Core_60_corpus.append(review)

Core_70_corpus = []
for i in range(0, len(Core_70)):
    review = re.sub('[^a-zA-Z]', ' ', Core_70['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Core_70_corpus.append(review)

Core_80_corpus = []
for i in range(0, len(Core_80)):
    review = re.sub('[^a-zA-Z]', ' ', Core_80['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Core_80_corpus.append(review)

Core_90_corpus = []
for i in range(0, len(Core_90)):
    review = re.sub('[^a-zA-Z]', ' ', Core_90['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Core_90_corpus.append(review)

Core_100_corpus = []
for i in range(0, len(Core_100)):
    review = re.sub('[^a-zA-Z]', ' ', Core_100['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Core_100_corpus.append(review)


import nltk
#nltk.download('averaged_perceptron_tagger')
from sklearn.feature_extraction import FeatureHasher
from nltk import pos_tag, word_tokenize

raw_X = (token_features(tok, pos_tag(tok)) for tok in Core_10_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Core_10_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Core_20_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Core_20_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Core_30_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Core_30_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Core_40_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Core_40_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Core_50_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Core_50_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Core_60_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Core_60_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Core_70_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Core_70_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Core_80_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Core_80_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Core_90_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Core_90_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Core_100_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Core_100_Hasher = hasher.transform(raw_X)


from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
m = TSNE(learning_rate=200)

tsne_features = m.fit_transform(Core_10_Hasher.toarray())
Core_10['x'] = tsne_features[:,0]
Core_10['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Core_20_Hasher.toarray())
Core_20['x'] = tsne_features[:,0]
Core_20['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Core_30_Hasher.toarray())
Core_30['x'] = tsne_features[:,0]
Core_30['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Core_40_Hasher.toarray())
Core_40['x'] = tsne_features[:,0]
Core_40['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Core_50_Hasher.toarray())
Core_50['x'] = tsne_features[:,0]
Core_50['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Core_60_Hasher.toarray())
Core_60['x'] = tsne_features[:,0]
Core_60['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Core_70_Hasher.toarray())
Core_70['x'] = tsne_features[:,0]
Core_70['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Core_80_Hasher.toarray())
Core_80['x'] = tsne_features[:,0]
Core_80['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Core_90_Hasher.toarray())
Core_90['x'] = tsne_features[:,0]
Core_90['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Core_100_Hasher.toarray())
Core_100['x'] = tsne_features[:,0]
Core_100['y'] = tsne_features[:,1]

# Plotting Final Figures

sns.set_style("whitegrid")
f, axes = plt.subplots(2, 5,figsize=(20, 8))
axes[1][0].set_ylabel(r"Core", fontsize=18,)
sns.scatterplot(x="x", y="y", hue='BRA', data= Core_10, ax= axes[0][0], legend= False)
axes[0][0].set_title("Iteration 1")
sns.scatterplot(x="x", y="y", hue='BRA', data= Core_20, ax= axes[0][1], legend= False)
axes[0][1].set_title("Iteration 2")
sns.scatterplot(x="x", y="y", hue='BRA', data= Core_30, ax= axes[0][2], legend= False)
axes[0][2].set_title("Iteration 3")
sns.scatterplot(x="x", y="y", hue='BRA', data= Core_40, ax= axes[0][3], legend= False)
axes[0][3].set_title("Iteration 4")
sns.scatterplot(x="x", y="y", hue='BRA', data= Core_50, ax= axes[0][4], )
axes[0][4].set_title("Iteration 5")
sns.scatterplot(x="x", y="y", hue='BRA', data= Core_60, ax= axes[1][0], legend= False)
axes[1][0].set_title("Iteration 6")
sns.scatterplot(x="x", y="y", hue='BRA', data= Core_70, ax= axes[1][1], legend= False)
axes[1][1].set_title("Iteration 7")
sns.scatterplot(x="x", y="y", hue='BRA', data= Core_80, ax= axes[1][2], legend= False)
axes[1][2].set_title("Iteration 8")
sns.scatterplot(x="x", y="y", hue='BRA', data= Core_90, ax= axes[1][3], legend= False)
axes[1][3].set_title("Iteration 9")
sns.scatterplot(x="x", y="y", hue='BRA', data= Core_100, ax= axes[1][4], legend= False)
axes[1][4].set_title("Iteration 10",)

for ax in axes:
  for axe in ax:
    axe.set_xlabel('')
    axe.set_ylabel('')
axes[1][0].set_ylabel(r"Core", fontsize=18, color="blue")
# Out:
# Text(0, 0.5, 'Core')

# %% [markdown]
# # Firefox Project

# %%
import pandas as pd
Firefox_10 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Firefox/Ex2_RQ3_Firefox_10.csv.xlsx')
Firefox_20 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Firefox/Ex2_RQ3_Firefox_20.csv.xlsx')
Firefox_30 = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Firefox/Ex2_RQ3_Firefox_30.csv')
Firefox_40 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Firefox/Ex2_RQ3_Firefox_40.csv.xlsx')
Firefox_50 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Firefox/Ex2_RQ3_Firefox_50.csv.xlsx')
Firefox_60 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Firefox/Ex2_RQ3_Firefox_60.csv.xlsx')
Firefox_70 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Firefox/Ex2_RQ3_Firefox_70.csv.xlsx')
Firefox_80 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Firefox/Ex2_RQ3_Firefox_80.csv.xlsx')
Firefox_90 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Firefox/Ex2_RQ3_Firefox_90.csv.xlsx')
Firefox_100 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Firefox/Ex2_RQ3_Firefox_100.csv.xlsx')

#Data cleaning and preprocessing
import re
import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
Firefox_10_corpus = []
for i in range(0, len(Firefox_10)):
    review = re.sub('[^a-zA-Z]', ' ', Firefox_10['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Firefox_10_corpus.append(review)

Firefox_20_corpus = []
for i in range(0, len(Firefox_20)):
    review = re.sub('[^a-zA-Z]', ' ', Firefox_20['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Firefox_20_corpus.append(review)

Firefox_30_corpus = []
for i in range(0, len(Firefox_30)):
    review = re.sub('[^a-zA-Z]', ' ', Firefox_30['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Firefox_30_corpus.append(review)

Firefox_40_corpus = []
for i in range(0, len(Firefox_40)):
    review = re.sub('[^a-zA-Z]', ' ', Firefox_40['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Firefox_40_corpus.append(review)

Firefox_50_corpus = []
for i in range(0, len(Firefox_50)):
    review = re.sub('[^a-zA-Z]', ' ', Firefox_50['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Firefox_50_corpus.append(review)

Firefox_60_corpus = []
for i in range(0, len(Firefox_60)):
    review = re.sub('[^a-zA-Z]', ' ', Firefox_60['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Firefox_60_corpus.append(review)

Firefox_70_corpus = []
for i in range(0, len(Firefox_70)):
    review = re.sub('[^a-zA-Z]', ' ', Firefox_70['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Firefox_70_corpus.append(review)

Firefox_80_corpus = []
for i in range(0, len(Firefox_80)):
    review = re.sub('[^a-zA-Z]', ' ', Firefox_80['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Firefox_80_corpus.append(review)

Firefox_90_corpus = []
for i in range(0, len(Firefox_90)):
    review = re.sub('[^a-zA-Z]', ' ', Firefox_90['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Firefox_90_corpus.append(review)

Firefox_100_corpus = []
for i in range(0, len(Firefox_100)):
    review = re.sub('[^a-zA-Z]', ' ', Firefox_100['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Firefox_100_corpus.append(review)


import nltk
#nltk.download('averaged_perceptron_tagger')
from sklearn.feature_extraction import FeatureHasher
from nltk import pos_tag, word_tokenize

raw_X = (token_features(tok, pos_tag(tok)) for tok in Firefox_10_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Firefox_10_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Firefox_20_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Firefox_20_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Firefox_30_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Firefox_30_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Firefox_40_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Firefox_40_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Firefox_50_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Firefox_50_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Firefox_60_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Firefox_60_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Firefox_70_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Firefox_70_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Firefox_80_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Firefox_80_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Firefox_90_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Firefox_90_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Firefox_100_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Firefox_100_Hasher = hasher.transform(raw_X)


from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
m = TSNE(learning_rate=200)

tsne_features = m.fit_transform(Firefox_10_Hasher.toarray())
Firefox_10['x'] = tsne_features[:,0]
Firefox_10['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Firefox_20_Hasher.toarray())
Firefox_20['x'] = tsne_features[:,0]
Firefox_20['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Firefox_30_Hasher.toarray())
Firefox_30['x'] = tsne_features[:,0]
Firefox_30['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Firefox_40_Hasher.toarray())
Firefox_40['x'] = tsne_features[:,0]
Firefox_40['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Firefox_50_Hasher.toarray())
Firefox_50['x'] = tsne_features[:,0]
Firefox_50['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Firefox_60_Hasher.toarray())
Firefox_60['x'] = tsne_features[:,0]
Firefox_60['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Firefox_70_Hasher.toarray())
Firefox_70['x'] = tsne_features[:,0]
Firefox_70['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Firefox_80_Hasher.toarray())
Firefox_80['x'] = tsne_features[:,0]
Firefox_80['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Firefox_90_Hasher.toarray())
Firefox_90['x'] = tsne_features[:,0]
Firefox_90['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Firefox_100_Hasher.toarray())
Firefox_100['x'] = tsne_features[:,0]
Firefox_100['y'] = tsne_features[:,1]

# Plotting Final Figures

sns.set_style("whitegrid")
f, axes = plt.subplots(2, 5,figsize=(20, 8))
axes[1][0].set_ylabel(r"Firefox", fontsize=18,)
sns.scatterplot(x="x", y="y", hue='BRA', data= Firefox_10, ax= axes[0][0], legend= False)
axes[0][0].set_title("Iteration 1")
sns.scatterplot(x="x", y="y", hue='BRA', data= Firefox_20, ax= axes[0][1], legend= False)
axes[0][1].set_title("Iteration 2")
sns.scatterplot(x="x", y="y", hue='BRA', data= Firefox_30, ax= axes[0][2], legend= False)
axes[0][2].set_title("Iteration 3")
sns.scatterplot(x="x", y="y", hue='BRA', data= Firefox_40, ax= axes[0][3], legend= False)
axes[0][3].set_title("Iteration 4")
sns.scatterplot(x="x", y="y", hue='BRA', data= Firefox_50, ax= axes[0][4], )
axes[0][4].set_title("Iteration 5")
sns.scatterplot(x="x", y="y", hue='BRA', data= Firefox_60, ax= axes[1][0], legend= False)
axes[1][0].set_title("Iteration 6")
sns.scatterplot(x="x", y="y", hue='BRA', data= Firefox_70, ax= axes[1][1], legend= False)
axes[1][1].set_title("Iteration 7")
sns.scatterplot(x="x", y="y", hue='BRA', data= Firefox_80, ax= axes[1][2], legend= False)
axes[1][2].set_title("Iteration 8")
sns.scatterplot(x="x", y="y", hue='BRA', data= Firefox_90, ax= axes[1][3], legend= False)
axes[1][3].set_title("Iteration 9")
sns.scatterplot(x="x", y="y", hue='BRA', data= Firefox_100, ax= axes[1][4], legend= False)
axes[1][4].set_title("Iteration 10",)

for ax in axes:
  for axe in ax:
    axe.set_xlabel('')
    axe.set_ylabel('')
axes[1][0].set_ylabel(r"Firefox", fontsize=18, color="blue")
# Out:
# Text(0, 0.5, 'Firefox')

# %% [markdown]
# # Mac Project

# %%
import pandas as pd
Mac_10 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Mac/Ex3_RQ3_Mac_10.csv.xlsx')
Mac_20 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Mac/Ex3_RQ3_Mac_20.csv.xlsx')
Mac_30 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Mac/Ex3_RQ3_Mac_30.csv.xlsx')
Mac_40 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Mac/Ex3_RQ3_Mac_40.csv.xlsx')
Mac_50 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Mac/Ex3_RQ3_Mac_50.csv.xlsx')
Mac_60 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Mac/Ex3_RQ3_Mac_60.csv.xlsx')
Mac_70 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Mac/Ex3_RQ3_Mac_70.csv.xlsx')
Mac_80 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Mac/Ex3_RQ3_Mac_80.csv.xlsx')
Mac_90 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Mac/Ex3_RQ3_Mac_90.csv.xlsx')
Mac_100 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Mac/Ex3_RQ3_Mac_100.csv.xlsx')

#Data cleaning and preprocessing
import re
import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
Mac_10_corpus = []
for i in range(0, len(Mac_10)):
    review = re.sub('[^a-zA-Z]', ' ', Mac_10['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Mac_10_corpus.append(review)

Mac_20_corpus = []
for i in range(0, len(Mac_20)):
    review = re.sub('[^a-zA-Z]', ' ', Mac_20['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Mac_20_corpus.append(review)

Mac_30_corpus = []
for i in range(0, len(Mac_30)):
    review = re.sub('[^a-zA-Z]', ' ', Mac_30['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Mac_30_corpus.append(review)

Mac_40_corpus = []
for i in range(0, len(Mac_40)):
    review = re.sub('[^a-zA-Z]', ' ', Mac_40['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Mac_40_corpus.append(review)

Mac_50_corpus = []
for i in range(0, len(Mac_50)):
    review = re.sub('[^a-zA-Z]', ' ', Mac_50['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Mac_50_corpus.append(review)

Mac_60_corpus = []
for i in range(0, len(Mac_60)):
    review = re.sub('[^a-zA-Z]', ' ', Mac_60['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Mac_60_corpus.append(review)

Mac_70_corpus = []
for i in range(0, len(Mac_70)):
    review = re.sub('[^a-zA-Z]', ' ', Mac_70['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Mac_70_corpus.append(review)

Mac_80_corpus = []
for i in range(0, len(Mac_80)):
    review = re.sub('[^a-zA-Z]', ' ', Mac_80['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Mac_80_corpus.append(review)

Mac_90_corpus = []
for i in range(0, len(Mac_90)):
    review = re.sub('[^a-zA-Z]', ' ', Mac_90['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Mac_90_corpus.append(review)

Mac_100_corpus = []
for i in range(0, len(Mac_100)):
    review = re.sub('[^a-zA-Z]', ' ', Mac_100['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Mac_100_corpus.append(review)


import nltk
#nltk.download('averaged_perceptron_tagger')
from sklearn.feature_extraction import FeatureHasher
from nltk import pos_tag, word_tokenize

raw_X = (token_features(tok, pos_tag(tok)) for tok in Mac_10_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Mac_10_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Mac_20_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Mac_20_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Mac_30_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Mac_30_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Mac_40_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Mac_40_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Mac_50_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Mac_50_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Mac_60_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Mac_60_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Mac_70_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Mac_70_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Mac_80_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Mac_80_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Mac_90_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Mac_90_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Mac_100_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Mac_100_Hasher = hasher.transform(raw_X)


from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
m = TSNE(learning_rate=200)

tsne_features = m.fit_transform(Mac_10_Hasher.toarray())
Mac_10['x'] = tsne_features[:,0]
Mac_10['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Mac_20_Hasher.toarray())
Mac_20['x'] = tsne_features[:,0]
Mac_20['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Mac_30_Hasher.toarray())
Mac_30['x'] = tsne_features[:,0]
Mac_30['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Mac_40_Hasher.toarray())
Mac_40['x'] = tsne_features[:,0]
Mac_40['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Mac_50_Hasher.toarray())
Mac_50['x'] = tsne_features[:,0]
Mac_50['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Mac_60_Hasher.toarray())
Mac_60['x'] = tsne_features[:,0]
Mac_60['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Mac_70_Hasher.toarray())
Mac_70['x'] = tsne_features[:,0]
Mac_70['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Mac_80_Hasher.toarray())
Mac_80['x'] = tsne_features[:,0]
Mac_80['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Mac_90_Hasher.toarray())
Mac_90['x'] = tsne_features[:,0]
Mac_90['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Mac_100_Hasher.toarray())
Mac_100['x'] = tsne_features[:,0]
Mac_100['y'] = tsne_features[:,1]

# Plotting Final Figures

sns.set_style("whitegrid")
f, axes = plt.subplots(2, 5,figsize=(20, 8))
axes[1][0].set_ylabel(r"Mac", fontsize=18,)
sns.scatterplot(x="x", y="y", hue='BRA', data= Mac_10, ax= axes[0][0], legend= False)
axes[0][0].set_title("Iteration 1")
sns.scatterplot(x="x", y="y", hue='BRA', data= Mac_20, ax= axes[0][1], legend= False)
axes[0][1].set_title("Iteration 2")
sns.scatterplot(x="x", y="y", hue='BRA', data= Mac_30, ax= axes[0][2], legend= False)
axes[0][2].set_title("Iteration 3")
sns.scatterplot(x="x", y="y", hue='BRA', data= Mac_40, ax= axes[0][3], legend= False)
axes[0][3].set_title("Iteration 4")
sns.scatterplot(x="x", y="y", hue='BRA', data= Mac_50, ax= axes[0][4], )
axes[0][4].set_title("Iteration 5")
sns.scatterplot(x="x", y="y", hue='BRA', data= Mac_60, ax= axes[1][0], legend= False)
axes[1][0].set_title("Iteration 6")
sns.scatterplot(x="x", y="y", hue='BRA', data= Mac_70, ax= axes[1][1], legend= False)
axes[1][1].set_title("Iteration 7")
sns.scatterplot(x="x", y="y", hue='BRA', data= Mac_80, ax= axes[1][2], legend= False)
axes[1][2].set_title("Iteration 8")
sns.scatterplot(x="x", y="y", hue='BRA', data= Mac_90, ax= axes[1][3], legend= False)
axes[1][3].set_title("Iteration 9")
sns.scatterplot(x="x", y="y", hue='BRA', data= Mac_100, ax= axes[1][4], legend= False)
axes[1][4].set_title("Iteration 10",)

for ax in axes:
  for axe in ax:
    axe.set_xlabel('')
    axe.set_ylabel('')
axes[1][0].set_ylabel(r"Mac", fontsize=18, color="blue")
# Out:
# Text(0, 0.5, 'Mac')

# %% [markdown]
# # NetBeans Project

# %%
import pandas as pd
NetBeans_10 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/NetBeans/Ex2_RQ3_NetBeans_10.csv.xlsx')
NetBeans_20 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/NetBeans/Ex2_RQ3_NetBeans_20.csv.xlsx')
NetBeans_30 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/NetBeans/Ex2_RQ3_NetBeans_30.csv.xlsx')
NetBeans_40 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/NetBeans/Ex2_RQ3_NetBeans_40.csv.xlsx')
NetBeans_50 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/NetBeans/Ex2_RQ3_NetBeans_50.csv.xlsx')
NetBeans_60 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/NetBeans/Ex2_RQ3_NetBeans_60.csv.xlsx')
NetBeans_70 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/NetBeans/Ex2_RQ3_NetBeans_70.csv.xlsx')
NetBeans_80 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/NetBeans/Ex2_RQ3_NetBeans_80.csv.xlsx')
NetBeans_90 = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/NetBeans/Ex2_RQ3_NetBeans_90.csv')
NetBeans_100 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/NetBeans/Ex2_RQ3_NetBeans_100.csv.xlsx')

#Data cleaning and preprocessing
import re
import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
NetBeans_10_corpus = []
for i in range(0, len(NetBeans_10)):
    review = re.sub('[^a-zA-Z]', ' ', NetBeans_10['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    NetBeans_10_corpus.append(review)

NetBeans_20_corpus = []
for i in range(0, len(NetBeans_20)):
    review = re.sub('[^a-zA-Z]', ' ', NetBeans_20['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    NetBeans_20_corpus.append(review)

NetBeans_30_corpus = []
for i in range(0, len(NetBeans_30)):
    review = re.sub('[^a-zA-Z]', ' ', NetBeans_30['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    NetBeans_30_corpus.append(review)

NetBeans_40_corpus = []
for i in range(0, len(NetBeans_40)):
    review = re.sub('[^a-zA-Z]', ' ', NetBeans_40['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    NetBeans_40_corpus.append(review)

NetBeans_50_corpus = []
for i in range(0, len(NetBeans_50)):
    review = re.sub('[^a-zA-Z]', ' ', NetBeans_50['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    NetBeans_50_corpus.append(review)

NetBeans_60_corpus = []
for i in range(0, len(NetBeans_60)):
    review = re.sub('[^a-zA-Z]', ' ', NetBeans_60['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    NetBeans_60_corpus.append(review)

NetBeans_70_corpus = []
for i in range(0, len(NetBeans_70)):
    review = re.sub('[^a-zA-Z]', ' ', NetBeans_70['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    NetBeans_70_corpus.append(review)

NetBeans_80_corpus = []
for i in range(0, len(NetBeans_80)):
    review = re.sub('[^a-zA-Z]', ' ', NetBeans_80['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    NetBeans_80_corpus.append(review)

NetBeans_90_corpus = []
for i in range(0, len(NetBeans_90)):
    review = re.sub('[^a-zA-Z]', ' ', NetBeans_90['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    NetBeans_90_corpus.append(review)

NetBeans_100_corpus = []
for i in range(0, len(NetBeans_100)):
    review = re.sub('[^a-zA-Z]', ' ', NetBeans_100['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    NetBeans_100_corpus.append(review)


import nltk
#nltk.download('averaged_perceptron_tagger')
from sklearn.feature_extraction import FeatureHasher
from nltk import pos_tag, word_tokenize

raw_X = (token_features(tok, pos_tag(tok)) for tok in NetBeans_10_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
NetBeans_10_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in NetBeans_20_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
NetBeans_20_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in NetBeans_30_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
NetBeans_30_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in NetBeans_40_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
NetBeans_40_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in NetBeans_50_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
NetBeans_50_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in NetBeans_60_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
NetBeans_60_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in NetBeans_70_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
NetBeans_70_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in NetBeans_80_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
NetBeans_80_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in NetBeans_90_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
NetBeans_90_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in NetBeans_100_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
NetBeans_100_Hasher = hasher.transform(raw_X)


from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
m = TSNE(learning_rate=200)

tsne_features = m.fit_transform(NetBeans_10_Hasher.toarray())
NetBeans_10['x'] = tsne_features[:,0]
NetBeans_10['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(NetBeans_20_Hasher.toarray())
NetBeans_20['x'] = tsne_features[:,0]
NetBeans_20['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(NetBeans_30_Hasher.toarray())
NetBeans_30['x'] = tsne_features[:,0]
NetBeans_30['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(NetBeans_40_Hasher.toarray())
NetBeans_40['x'] = tsne_features[:,0]
NetBeans_40['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(NetBeans_50_Hasher.toarray())
NetBeans_50['x'] = tsne_features[:,0]
NetBeans_50['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(NetBeans_60_Hasher.toarray())
NetBeans_60['x'] = tsne_features[:,0]
NetBeans_60['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(NetBeans_70_Hasher.toarray())
NetBeans_70['x'] = tsne_features[:,0]
NetBeans_70['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(NetBeans_80_Hasher.toarray())
NetBeans_80['x'] = tsne_features[:,0]
NetBeans_80['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(NetBeans_90_Hasher.toarray())
NetBeans_90['x'] = tsne_features[:,0]
NetBeans_90['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(NetBeans_100_Hasher.toarray())
NetBeans_100['x'] = tsne_features[:,0]
NetBeans_100['y'] = tsne_features[:,1]

# Plotting Final Figures

sns.set_style("whitegrid")
f, axes = plt.subplots(2, 5,figsize=(20, 8))
axes[1][0].set_ylabel(r"NetBeans", fontsize=18,)
sns.scatterplot(x="x", y="y", hue='BRA', data= NetBeans_10, ax= axes[0][0], legend= False)
axes[0][0].set_title("Iteration 1")
sns.scatterplot(x="x", y="y", hue='BRA', data= NetBeans_20, ax= axes[0][1], legend= False)
axes[0][1].set_title("Iteration 2")
sns.scatterplot(x="x", y="y", hue='BRA', data= NetBeans_30, ax= axes[0][2], legend= False)
axes[0][2].set_title("Iteration 3")
sns.scatterplot(x="x", y="y", hue='BRA', data= NetBeans_40, ax= axes[0][3], legend= False)
axes[0][3].set_title("Iteration 4")
sns.scatterplot(x="x", y="y", hue='BRA', data= NetBeans_50, ax= axes[0][4], )
axes[0][4].set_title("Iteration 5")
sns.scatterplot(x="x", y="y", hue='BRA', data= NetBeans_60, ax= axes[1][0], legend= False)
axes[1][0].set_title("Iteration 6")
sns.scatterplot(x="x", y="y", hue='BRA', data= NetBeans_70, ax= axes[1][1], legend= False)
axes[1][1].set_title("Iteration 7")
sns.scatterplot(x="x", y="y", hue='BRA', data= NetBeans_80, ax= axes[1][2], legend= False)
axes[1][2].set_title("Iteration 8")
sns.scatterplot(x="x", y="y", hue='BRA', data= NetBeans_90, ax= axes[1][3], legend= False)
axes[1][3].set_title("Iteration 9")
sns.scatterplot(x="x", y="y", hue='BRA', data= NetBeans_100, ax= axes[1][4], legend= False)
axes[1][4].set_title("Iteration 10",)

for ax in axes:
  for axe in ax:
    axe.set_xlabel('')
    axe.set_ylabel('')
axes[1][0].set_ylabel(r"NetBeans", fontsize=18, color="blue")
# Out:
# Text(0, 0.5, 'NetBeans')

# %% [markdown]
# # Windows Project

# %%
import pandas as pd
Windows_10 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Windows/Ex2_RQ3_Windows_10.csv.xlsx')
Windows_20 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Windows/Ex2_RQ3_Windows_20.csv.xlsx')
Windows_30 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Windows/Ex2_RQ3_Windows_30.csv.xlsx')
Windows_40 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Windows/Ex2_RQ3_Windows_40.csv.xlsx')
Windows_50 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Windows/Ex2_RQ3_Windows_50.csv.xlsx')
Windows_60 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Windows/Ex2_RQ3_Windows_60.csv.xlsx')
Windows_70 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Windows/Ex2_RQ3_Windows_70.csv.xlsx')
Windows_80 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Windows/Ex2_RQ3_Windows_80.csv.xlsx')
Windows_90 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Windows/Ex2_RQ3_Windows_90.csv.xlsx')
Windows_100 = pd.read_excel('/content/gdrive/My Drive/Colab Notebooks/Datasets/Wajdi/Windows/Ex2_RQ3_Windows_100.csv.xlsx')

#Data cleaning and preprocessing
import re
import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
Windows_10_corpus = []
for i in range(0, len(Windows_10)):
    review = re.sub('[^a-zA-Z]', ' ', Windows_10['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Windows_10_corpus.append(review)

Windows_20_corpus = []
for i in range(0, len(Windows_20)):
    review = re.sub('[^a-zA-Z]', ' ', Windows_20['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Windows_20_corpus.append(review)

Windows_30_corpus = []
for i in range(0, len(Windows_30)):
    review = re.sub('[^a-zA-Z]', ' ', Windows_30['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Windows_30_corpus.append(review)

Windows_40_corpus = []
for i in range(0, len(Windows_40)):
    review = re.sub('[^a-zA-Z]', ' ', Windows_40['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Windows_40_corpus.append(review)

Windows_50_corpus = []
for i in range(0, len(Windows_50)):
    review = re.sub('[^a-zA-Z]', ' ', Windows_50['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Windows_50_corpus.append(review)

Windows_60_corpus = []
for i in range(0, len(Windows_60)):
    review = re.sub('[^a-zA-Z]', ' ', Windows_60['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Windows_60_corpus.append(review)

Windows_70_corpus = []
for i in range(0, len(Windows_70)):
    review = re.sub('[^a-zA-Z]', ' ', Windows_70['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Windows_70_corpus.append(review)

Windows_80_corpus = []
for i in range(0, len(Windows_80)):
    review = re.sub('[^a-zA-Z]', ' ', Windows_80['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Windows_80_corpus.append(review)

Windows_90_corpus = []
for i in range(0, len(Windows_90)):
    review = re.sub('[^a-zA-Z]', ' ', Windows_90['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Windows_90_corpus.append(review)

Windows_100_corpus = []
for i in range(0, len(Windows_100)):
    review = re.sub('[^a-zA-Z]', ' ', Windows_100['Summary'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    Windows_100_corpus.append(review)


import nltk
#nltk.download('averaged_perceptron_tagger')
from sklearn.feature_extraction import FeatureHasher
from nltk import pos_tag, word_tokenize

raw_X = (token_features(tok, pos_tag(tok)) for tok in Windows_10_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Windows_10_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Windows_20_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Windows_20_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Windows_30_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Windows_30_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Windows_40_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Windows_40_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Windows_50_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Windows_50_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Windows_60_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Windows_60_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Windows_70_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Windows_70_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Windows_80_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Windows_80_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Windows_90_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Windows_90_Hasher = hasher.transform(raw_X)

raw_X = (token_features(tok, pos_tag(tok)) for tok in Windows_100_corpus)
hasher = FeatureHasher(input_type='string', n_features=200)
Windows_100_Hasher = hasher.transform(raw_X)


from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
m = TSNE(learning_rate=200)

tsne_features = m.fit_transform(Windows_10_Hasher.toarray())
Windows_10['x'] = tsne_features[:,0]
Windows_10['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Windows_20_Hasher.toarray())
Windows_20['x'] = tsne_features[:,0]
Windows_20['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Windows_30_Hasher.toarray())
Windows_30['x'] = tsne_features[:,0]
Windows_30['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Windows_40_Hasher.toarray())
Windows_40['x'] = tsne_features[:,0]
Windows_40['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Windows_50_Hasher.toarray())
Windows_50['x'] = tsne_features[:,0]
Windows_50['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Windows_60_Hasher.toarray())
Windows_60['x'] = tsne_features[:,0]
Windows_60['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Windows_70_Hasher.toarray())
Windows_70['x'] = tsne_features[:,0]
Windows_70['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Windows_80_Hasher.toarray())
Windows_80['x'] = tsne_features[:,0]
Windows_80['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Windows_90_Hasher.toarray())
Windows_90['x'] = tsne_features[:,0]
Windows_90['y'] = tsne_features[:,1]

tsne_features = m.fit_transform(Windows_100_Hasher.toarray())
Windows_100['x'] = tsne_features[:,0]
Windows_100['y'] = tsne_features[:,1]

# Plotting Final Figures

sns.set_style("whitegrid")
f, axes = plt.subplots(2, 5,figsize=(20, 8))
axes[1][0].set_ylabel(r"Windows", fontsize=18,)
sns.scatterplot(x="x", y="y", hue='BRA', data= Windows_10, ax= axes[0][0], legend= False)
axes[0][0].set_title("Iteration 1")
sns.scatterplot(x="x", y="y", hue='BRA', data= Windows_20, ax= axes[0][1], legend= False)
axes[0][1].set_title("Iteration 2")
sns.scatterplot(x="x", y="y", hue='BRA', data= Windows_30, ax= axes[0][2], legend= False)
axes[0][2].set_title("Iteration 3")
sns.scatterplot(x="x", y="y", hue='BRA', data= Windows_40, ax= axes[0][3], legend= False)
axes[0][3].set_title("Iteration 4")
sns.scatterplot(x="x", y="y", hue='BRA', data= Windows_50, ax= axes[0][4], )
axes[0][4].set_title("Iteration 5")
sns.scatterplot(x="x", y="y", hue='BRA', data= Windows_60, ax= axes[1][0], legend= False)
axes[1][0].set_title("Iteration 6")
sns.scatterplot(x="x", y="y", hue='BRA', data= Windows_70, ax= axes[1][1], legend= False)
axes[1][1].set_title("Iteration 7")
sns.scatterplot(x="x", y="y", hue='BRA', data= Windows_80, ax= axes[1][2], legend= False)
axes[1][2].set_title("Iteration 8")
sns.scatterplot(x="x", y="y", hue='BRA', data= Windows_90, ax= axes[1][3], legend= False)
axes[1][3].set_title("Iteration 9")
sns.scatterplot(x="x", y="y", hue='BRA', data= Windows_100, ax= axes[1][4], legend= False)
axes[1][4].set_title("Iteration 10",)

for ax in axes:
  for axe in ax:
    axe.set_xlabel('')
    axe.set_ylabel('')
axes[1][0].set_ylabel(r"Windows", fontsize=18, color="blue")
# Out:
# Text(0, 0.5, 'Windows')
